# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# Out:
# /home/mijia/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/mijia/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/mijia/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/mijia/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# ...

# %%
Soc_TwitchFr = nx.read_edgelist("datasets/Soc-Twitch-Fr", delimiter = ',', create_using=nx.Graph)

# %%
FW_Baydry = nx.read_edgelist("datasets/FW-Baydry", create_using=nx.Graph, data = (('weight', float),))
FW_LittleRock = nx.read_edgelist("datasets/FW-LittleRock", create_using=nx.Graph)

Soc_EmailEu = nx.read_edgelist("datasets/Soc-EmailEu", create_using=nx.Graph, data=(('sec', int),))
Soc_Msg = nx.read_edgelist("datasets/CollegeMsg", create_using=nx.Graph, data=(('sec', int),))
Soc_Alpha = nx.read_edgelist("datasets/BTC-Alpha", delimiter = ',', create_using=nx.Graph, data=(('weight', int),('sec', int),))
Soc_FB = nx.read_edgelist("datasets/Soc-FB", delimiter = ',', create_using=nx.Graph)

PPI_Stelzl = nx.read_edgelist("datasets/HP-Stelzl", create_using=nx.Graph)
PPI_Figeys = nx.read_edgelist("datasets/HP-Figeys", create_using=nx.Graph)
PPI_Vidal = nx.read_edgelist("datasets/HP-Vidal", create_using=nx.Graph)
PPI_IntAct = nx.read_edgelist("datasets/HP-IntAct", create_using=nx.Graph)

Cit_DBLP = nx.read_edgelist("datasets/Cit-DBLP", create_using=nx.Graph, data=(('weight', int),('sec', int),))
Cit_Cora = nx.read_edgelist("datasets/Cit-Cora", create_using=nx.Graph)

Road_NY = nx.read_edgelist("datasets/Road-NY", create_using=nx.Graph)
Road_Bay = nx.read_edgelist("datasets/Road-BayArea", create_using=nx.Graph)

QA_Math = nx.read_edgelist("datasets/QA-MathOvfl-a2q", create_using=nx.Graph, data=(('sec', int),))
QA_Ubuntu = nx.read_edgelist("datasets/QA-AskUbuntu-a2q", create_using=nx.Graph, data=(('sec', int),))

# %%
onepic, axes = plt.subplots(3,2,figsize=(9,10))
plt.subplots_adjust(hspace=0.35, wspace=.2) 
axes[0, 0].hist(iquad_2, bins=50, density=True, histtype='step',cumulative=True, linewidth=1.3, color="forestgreen", label="I(i)")
axes[0, 0].hist(oquad_2, bins=50, density=True, histtype='step',cumulative=True, linewidth=1.3, color="mediumslateblue", label="O(i)")
axes[0, 0].legend(loc='lower right', prop={'size': 12})
axes[0, 0].set_title("FW-LittleRock", fontsize=16)
#axes[0, 0].set_ylabel("CDF", fontsize=28)

axes[0, 1].hist(iquad_3, bins=50, density=True, histtype='step',cumulative=True, linewidth=1.3, color="forestgreen", label="I(i)")
axes[0, 1].hist(oquad_3, bins=50, density=True, histtype='step',cumulative=True, linewidth=1.3, color="mediumslateblue", label="O(i)")
axes[0, 1].legend(loc='lower right', prop={'size': 12})
axes[0, 1].set_title("Soc-EmailEu", fontsize=16)

axes[1, 0].hist(iquad_8, bins=50, density=True, histtype='step',cumulative=True, linewidth=1.3, color="forestgreen", label="I(i)")
axes[1, 0].hist(oquad_8, bins=50, density=True, histtype='step',cumulative=True, linewidth=1.3, color="mediumslateblue", label="O(i)")
axes[1, 0].legend(loc='lower right', prop={'size': 12})
axes[1, 0].set_title("PPI-Figeys", fontsize=16)
#axes[1, 0].set_ylabel("CDF", fontsize=28)

axes[1, 1].hist(iquad_12, bins=50, density=True, histtype='step',cumulative=True, linewidth=1.3, color="forestgreen", label="I(i)")
axes[1, 1].hist(oquad_12, bins=50, density=True, histtype='step',cumulative=True, linewidth=1.3, color="mediumslateblue", label="O(i)")
axes[1, 1].legend(loc='lower right', prop={'size': 12})
axes[1, 1].set_title("Cit-Cora", fontsize=16)

axes[2, 0].hist(iquad_13, bins=50, density=True, histtype='step',cumulative=True, linewidth=1.3, color="forestgreen", label="I(i)")
axes[2, 0].hist(oquad_13, bins=50, density=True, histtype='step',cumulative=True, linewidth=1.3, color="mediumslateblue", label="O(i)")
axes[2, 0].legend(loc='lower right', prop={'size': 12})
axes[2, 0].set_title("Rd-NewYork", fontsize=16)
axes[2, 0].set_xlabel("i-quad / o-quad coef.", fontsize=14)

axes[2, 1].hist(iquad_15, bins=50, density=True, histtype='step',cumulative=True, linewidth=1.3, color="forestgreen", label="I(i)")
axes[2, 1].hist(oquad_15, bins=50, density=True, histtype='step',cumulative=True, linewidth=1.3, color="mediumslateblue", label="O(i)")
axes[2, 1].legend(loc='lower right', prop={'size': 12})
axes[2, 1].set_title("QA-MathOvfl.", fontsize=16)
axes[2, 1].set_xlabel("i-quad / o-quad coef.", fontsize=14)

plt.savefig('CDF.pdf')

# %%
clu_6, clo_6, iquad_6, oquad_6 = nx.get_four_coefs(Soc_TwitchFr)

# %%
clu_1, clo_1, iquad_1, oquad_1 = nx.get_four_coefs(FW_Baydry)
clu_2, clo_2, iquad_2, oquad_2 = nx.get_four_coefs(FW_LittleRock)

clu_3, clo_3, iquad_3, oquad_3 = nx.get_four_coefs(Soc_EmailEu)
clu_4, clo_4, iquad_4, oquad_4 = nx.get_four_coefs(Soc_Msg)
clu_5, clo_5, iquad_5, oquad_5 = nx.get_four_coefs(Soc_Alpha)
# clu_6, clo_6, iquad_6, oquad_6 = nx.get_four_coefs(Soc_FB)
clu_6, clo_6, iquad_6, oquad_6 = nx.get_four_coefs(Soc_TwitchFr)

clu_7, clo_7, iquad_7, oquad_7 = nx.get_four_coefs(PPI_Stelzl)
clu_8, clo_8, iquad_8, oquad_8 = nx.get_four_coefs(PPI_Figeys)
clu_9, clo_9, iquad_9, oquad_9 = nx.get_four_coefs(PPI_Vidal)
clu_10, clo_10, iquad_10, oquad_10 = nx.get_four_coefs(PPI_IntAct)

clu_11, clo_11, iquad_11, oquad_11 = nx.get_four_coefs(Cit_DBLP)
clu_12, clo_12, iquad_12, oquad_12 = nx.get_four_coefs(Cit_Cora)

clu_13, clo_13, iquad_13, oquad_13 = nx.get_four_coefs(Road_NY)
clu_14, clo_14, iquad_14, oquad_14 = nx.get_four_coefs(Road_Bay)

clu_15, clo_15, iquad_15, oquad_15 = nx.get_four_coefs(QA_Math)
clu_16, clo_16, iquad_16, oquad_16 = nx.get_four_coefs(QA_Ubuntu)

# %%
onepic, axes = plt.subplots(4,4,figsize=(18,10.4))
plt.subplots_adjust(hspace=0.4, wspace=.2) 

axes[0, 0].hist(iquad_1, bins=50, density=True, histtype='step',cumulative=True, color="forestgreen", label="I(i)")
axes[0, 0].hist(oquad_1, bins=50, density=True, histtype='step',cumulative=True, color="mediumslateblue", label="O(i)")
axes[0, 0].legend(loc='lower right')
axes[0, 0].set_title("FW-Baydry")
axes[0, 0].set_ylabel("cumulative probability")

axes[0, 1].hist(iquad_2, bins=50, density=True, histtype='step',cumulative=True, color="forestgreen", label="I(i)")
axes[0, 1].hist(oquad_2, bins=50, density=True, histtype='step',cumulative=True, color="mediumslateblue", label="O(i)")
axes[0, 1].legend(loc='lower right')
axes[0, 1].set_title("FW-LittleRock")

axes[0, 2].hist(iquad_3, bins=50, density=True, histtype='step',cumulative=True, color="forestgreen", label="I(i)")
axes[0, 2].hist(oquad_3, bins=50, density=True, histtype='step',cumulative=True, color="mediumslateblue", label="O(i)")
axes[0, 2].legend(loc='lower right')
axes[0, 2].set_title("Soc-EmailEu")

axes[0, 3].hist(iquad_4, bins=50, density=True, histtype='step',cumulative=True, color="forestgreen", label="I(i)")
axes[0, 3].hist(oquad_4, bins=50, density=True, histtype='step',cumulative=True, color="mediumslateblue", label="O(i)")
axes[0, 3].legend(loc='lower right')
axes[0, 3].set_title("Soc-ClgMsg")

axes[1, 0].hist(iquad_5, bins=50, density=True, histtype='step',cumulative=True, color="forestgreen", label="I(i)")
axes[1, 0].hist(oquad_5, bins=50, density=True, histtype='step',cumulative=True, color="mediumslateblue", label="O(i)")
axes[1, 0].legend(loc='lower right')
axes[1, 0].set_title("Soc-BTCAlpha")
# axes[1, 0].set_xlabel("Four coefs.")
axes[1, 0].set_ylabel("cumulative probability")

axes[1, 1].hist(iquad_6, bins=50, density=True, histtype='step',cumulative=True, color="forestgreen", label="I(i)")
axes[1, 1].hist(oquad_6, bins=50, density=True, histtype='step',cumulative=True, color="mediumslateblue", label="O(i)")
axes[1, 1].legend(loc='lower right')
axes[1, 1].set_title("Soc-TwitchFr")
# axes[1, 1].set_xlabel("Four coefs.")

axes[1, 2].hist(iquad_7, bins=50, density=True, histtype='step',cumulative=True, color="forestgreen", label="I(i)")
axes[1, 2].hist(oquad_7, bins=50, density=True, histtype='step',cumulative=True, color="mediumslateblue", label="O(i)")
axes[1, 2].legend(loc='lower right')
axes[1, 2].set_title("PPI-Stelzl")

axes[1, 3].hist(iquad_8, bins=50, density=True, histtype='step',cumulative=True, color="forestgreen", label="I(i)")
axes[1, 3].hist(oquad_8, bins=50, density=True, histtype='step',cumulative=True, color="mediumslateblue", label="O(i)")
axes[1, 3].legend(loc='lower right')
axes[1, 3].set_title("PPI-Figeys")

axes[2, 0].hist(iquad_9, bins=50, density=True, histtype='step',cumulative=True, color="forestgreen", label="I(i)")
axes[2, 0].hist(oquad_9, bins=50, density=True, histtype='step',cumulative=True, color="mediumslateblue", label="O(i)")
axes[2, 0].legend(loc='lower right')
axes[2, 0].set_title("PPI-Vidal")
# axes[1, 0].set_xlabel("Four coefs.")
axes[2, 0].set_ylabel("cumulative probability")

axes[2, 1].hist(iquad_10, bins=50, density=True, histtype='step',cumulative=True, color="forestgreen", label="I(i)")
axes[2, 1].hist(oquad_10, bins=50, density=True, histtype='step',cumulative=True, color="mediumslateblue", label="O(i)")
axes[2, 1].legend(loc='lower right')
axes[2, 1].set_title("PPI-IntAct")
# axes[1, 1].set_xlabel("Four coefs.")

axes[2, 2].hist(iquad_11, bins=50, density=True, histtype='step',cumulative=True, color="forestgreen", label="I(i)")
axes[2, 2].hist(oquad_11, bins=50, density=True, histtype='step',cumulative=True, color="mediumslateblue", label="O(i)")
axes[2, 2].legend(loc='lower right')
axes[2, 2].set_title("Cit-DBLP")

axes[2, 3].hist(iquad_12, bins=50, density=True, histtype='step',cumulative=True, color="forestgreen", label="I(i)")
axes[2, 3].hist(oquad_12, bins=50, density=True, histtype='step',cumulative=True, color="mediumslateblue", label="O(i)")
axes[2, 3].legend(loc='lower right')
axes[2, 3].set_title("Cit-Cora")

axes[3, 0].hist(iquad_13, bins=50, density=True, histtype='step',cumulative=True, color="forestgreen", label="I(i)")
axes[3, 0].hist(oquad_13, bins=50, density=True, histtype='step',cumulative=True, color="mediumslateblue", label="O(i)")
axes[3, 0].legend(loc='lower right')
axes[3, 0].set_title("Rd-NewYork")
# axes[1, 0].set_xlabel("Four coefs.")
axes[3, 0].set_ylabel("cumulative probability")

axes[3, 1].hist(iquad_14, bins=50, density=True, histtype='step',cumulative=True, color="forestgreen", label="I(i)")
axes[3, 1].hist(oquad_14, bins=50, density=True, histtype='step',cumulative=True, color="mediumslateblue", label="O(i)")
axes[3, 1].legend(loc='lower right')
axes[3, 1].set_title("Rd-BayArea")
# axes[1, 1].set_xlabel("Four coefs.")

axes[3, 2].hist(iquad_15, bins=50, density=True, histtype='step',cumulative=True, color="forestgreen", label="I(i)")
axes[3, 2].hist(oquad_15, bins=50, density=True, histtype='step',cumulative=True, color="mediumslateblue", label="O(i)")
axes[3, 2].legend(loc='lower right')
axes[3, 2].set_title("QA-MathOvfl.")
# axes[1, 1].set_xlabel("Four coefs.")

axes[3, 3].hist(iquad_16, bins=50, density=True, histtype='step',cumulative=True, color="forestgreen", label="I(i)")
axes[3, 3].hist(oquad_16, bins=50, density=True, histtype='step',cumulative=True, color="mediumslateblue", label="O(i)")
axes[3, 3].legend(loc='lower right')
axes[3, 3].set_title("QA-AskUbuntu")
# axes[1, 1].set_xlabel("Four coefs.")
plt.savefig('CDF_all.pdf')
plt.show()
