# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib
from scipy.stats.stats import pearsonr

# %%
FW_Baydry = nx.read_edgelist("datasets/FW-Baydry", create_using=nx.Graph, data = (('weight', float),))
FW_LittleRock = nx.read_edgelist("datasets/FW-LittleRock", create_using=nx.Graph)

Soc_EmailEu = nx.read_edgelist("datasets/Soc-EmailEu", create_using=nx.Graph, data=(('sec', int),))
Soc_Msg = nx.read_edgelist("datasets/CollegeMsg", create_using=nx.Graph, data=(('sec', int),))
Soc_Alpha = nx.read_edgelist("datasets/BTC-Alpha", delimiter = ',', create_using=nx.Graph, data=(('weight', int),('sec', int),))
Soc_FB = nx.read_edgelist("datasets/Soc-FB", delimiter = ',', create_using=nx.Graph)
Soc_Twitch = nx.read_edgelist("datasets/Soc-Twitch-Fr", delimiter = ',', create_using=nx.Graph)

PPI_Stelzl = nx.read_edgelist("datasets/HP-Stelzl", create_using=nx.Graph)
PPI_Figeys = nx.read_edgelist("datasets/HP-Figeys", create_using=nx.Graph)
PPI_Vidal = nx.read_edgelist("datasets/HP-Vidal", create_using=nx.Graph)
PPI_IntAct = nx.read_edgelist("datasets/HP-IntAct", create_using=nx.Graph)

Cit_DBLP = nx.read_edgelist("datasets/Cit-DBLP", create_using=nx.Graph, data=(('weight', int),('sec', int),))
Cit_Cora = nx.read_edgelist("datasets/Cit-Cora", create_using=nx.Graph)

Road_NY = nx.read_edgelist("datasets/Road-NY", create_using=nx.Graph)
Road_Bay = nx.read_edgelist("datasets/Road-BayArea", create_using=nx.Graph)

QA_Math = nx.read_edgelist("datasets/QA-MathOvfl-a2q", create_using=nx.Graph, data=(('sec', int),))
QA_Ubuntu = nx.read_edgelist("datasets/QA-AskUbuntu-a2q", create_using=nx.Graph, data=(('sec', int),))

# %%
print(pearsonr(x_1, iquad_1))
print(pearsonr(x_1, oquad_1))
print()
print(pearsonr(x_6[:], iquad_6[:]))
print(pearsonr(x_6[:], oquad_6[:]))
print()
print(pearsonr(x_10[:], iquad_10[:]))
print(pearsonr(x_10[:], oquad_10[:]))
print()
print(pearsonr(x_12[:], iquad_12[:]))
print(pearsonr(x_12[:], oquad_12[:]))
print()
print(pearsonr(x_14[:], iquad_14[:]))
print(pearsonr(x_14[:], oquad_14[:]))
print()
print(pearsonr(x_15[:], iquad_15[:]))
print(pearsonr(x_15[:], oquad_15[:]))
# Out:
# (0.1829693937607942, 0.612886788311337)
# (0.9825926189378758, 3.933786876799896e-07)
#
# (0.4618066064378084, 0.1790712617065169)
# (0.9250806241698009, 0.00012582446769849372)
#
# (0.26304515567212, 0.46277732758149215)
# (0.8953893217748312, 0.0004609929431743354)
#
# (0.048341661796225344, 0.8944993912948316)
# (0.9087268220074851, 0.00027162611276092046)
#
# (0.9794797556796402, 7.567868223389409e-07)
# (0.9536093415744565, 1.915648654855697e-05)
#
# (0.4414987091660856, 0.20147754375101135)
# (0.9994412034618039, 4.2628655629815114e-13)

# %%
x_6, _, _, iquad_6, oquad_6 = nx.degree_coefs_corr(Soc_Twitch)

# %%
x_1, _, _, iquad_1, oquad_1 = nx.degree_coefs_corr(FW_Baydry)
x_2, _, _, iquad_2, oquad_2 = nx.degree_coefs_corr(FW_LittleRock)

x_3, _, _, iquad_3, oquad_3 = nx.degree_coefs_corr(Soc_EmailEu)
x_4, _, _, iquad_4, oquad_4 = nx.degree_coefs_corr(Soc_Msg)
x_5, _, _, iquad_5, oquad_5 = nx.degree_coefs_corr(Soc_Alpha)
x_6, _, _, iquad_6, oquad_6 = nx.degree_coefs_corr(Soc_Twitch)

x_7, _, _, iquad_7, oquad_7 = nx.degree_coefs_corr(PPI_Stelzl)
x_8, _, _, iquad_8, oquad_8 = nx.degree_coefs_corr(PPI_Figeys)
x_9, _, _, iquad_9, oquad_9 = nx.degree_coefs_corr(PPI_Vidal)
x_10, _, _, iquad_10, oquad_10 = nx.degree_coefs_corr(PPI_IntAct)

x_11, _, _, iquad_11, oquad_11 = nx.degree_coefs_corr(Cit_DBLP)
x_12, _, _, iquad_12, oquad_12 = nx.degree_coefs_corr(Cit_Cora)

x_13, _, _, iquad_13, oquad_13 = nx.degree_coefs_corr(Road_NY)
x_14, _, _, iquad_14, oquad_14 = nx.degree_coefs_corr(Road_Bay)

x_15, _, _, iquad_15, oquad_15 = nx.degree_coefs_corr(QA_Math)
x_16, _, _, iquad_16, oquad_16 = nx.degree_coefs_corr(QA_Ubuntu)

# %%
# pick 6
onepic, axes = plt.subplots(3,2,figsize=(9,10))
plt.subplots_adjust(hspace=0.35, wspace=.2) 

axes[0, 0].plot(x_1, iquad_1, '-s', label='I(i)', color="forestgreen")
axes[0, 0].plot(x_1, oquad_1, '--D', label='O(i)', color="mediumslateblue")
axes[0, 0].set_title("FW-Baydry", fontsize=16)
axes[0, 0].legend(loc='lower right', prop={'size': 12})
axes[0, 0].set_ylabel("i-quad / o-quad coef.", fontsize=12)
axes[0, 0].set_xscale('log')
axes[0, 0].set_yscale('log')
axes[0, 0].set_yticks([0.20, 0.30, 0.40, 0.60])
axes[0, 0].get_yaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())

axes[0, 1].plot(x_6, iquad_6, '-s', label='I(i)', color="forestgreen")
axes[0, 1].plot(x_6, oquad_6, '--D', label='O(i)', color="mediumslateblue")
axes[0, 1].set_title("Soc-TwitchFr", fontsize=16)
axes[0, 1].legend(loc='lower right', prop={'size': 12})
axes[0, 1].set_xscale('log')
axes[0, 1].set_yscale('log')

axes[1, 0].plot(x_10[3:], iquad_10[3:], '-s', label='I(i)', color="forestgreen")
axes[1, 0].plot(x_10[3:], oquad_10[3:], '--D', label='O(i)', color="mediumslateblue")
axes[1, 0].set_title("PPI-IntAct", fontsize=16)
axes[1, 0].legend(loc='lower right', prop={'size': 12})
axes[1, 0].set_ylabel("i-quad / o-quad coef.", fontsize=12)
axes[1, 0].set_xscale('log')
axes[1, 0].set_yscale('log')
axes[1, 0].set_yticks([0.1])
axes[1, 0].get_yaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())

axes[1, 1].plot(x_12[1:], iquad_12[1:], '-s', label='I(i)', color="forestgreen")
axes[1, 1].plot(x_12[1:], oquad_12[1:], '--D', label='O(i)', color="mediumslateblue")
axes[1, 1].set_title("Cit-Cora", fontsize=16)
axes[1, 1].legend(loc='lower right', prop={'size': 12})
axes[1, 1].set_xscale('log')
axes[1, 1].set_yscale('log')

axes[2, 0].plot(x_14[2:], iquad_14[2:], '-s', label='I(i)', color="forestgreen")
axes[2, 0].plot(x_14[2:], oquad_14[2:], '--D', label='O(i)', color="mediumslateblue")
axes[2, 0].set_title("Rd-BayArea", fontsize=16)
axes[2, 0].legend(loc='lower right', prop={'size': 12})
axes[2, 0].set_xlabel("degree", fontsize=14)
axes[2, 0].set_ylabel("i-quad / o-quad coef.", fontsize=12)
axes[2, 0].set_xscale('log')
axes[2, 0].set_yscale('log')
axes[2, 0].set_yticks([0.1])
axes[2, 0].get_yaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())

axes[2, 1].plot(x_15[4:], iquad_15[4:], '-s', label='I(i)', color="forestgreen")
axes[2, 1].plot(x_15[4:], oquad_15[4:], '--D', label='O(i)', color="mediumslateblue")
axes[2, 1].set_title("QA-MathOvfl.", fontsize=16)
axes[2, 1].legend(loc='lower right', prop={'size': 12})
axes[2, 1].set_xlabel("degree", fontsize=14)
axes[2, 1].set_xscale('log')
axes[2, 1].set_yscale('log')

plt.savefig('Corr_with_degree.pdf')

# %%
# for all 16 
onepic, axes = plt.subplots(4,4,figsize=(18,10.4))
plt.subplots_adjust(hspace=0.4, wspace=.2) 

axes[0, 0].plot(x_1, iquad_1, '-s', label='I(i)', color="forestgreen")
axes[0, 0].plot(x_1, oquad_1, '--D', label='O(i)', color="mediumslateblue")
axes[0, 0].set_title("FW-Baydry", fontsize=16)
axes[0, 0].legend(loc='lower right', prop={'size': 12})
axes[0, 0].set_ylabel("i-quad/o-quad coefs.", fontsize=12)
axes[0, 0].set_xscale('log')
axes[0, 0].set_yscale('log')

axes[0, 1].plot(x_2, iquad_2, '-s', label='I(i)', color="forestgreen")
axes[0, 1].plot(x_2, oquad_2, '--D', label='O(i)', color="mediumslateblue")
axes[0, 1].set_title("FW-LittleRock", fontsize=16)
axes[0, 1].legend(loc='lower right', prop={'size': 12})
axes[0, 1].set_xscale('log')
axes[0, 1].set_yscale('log')

axes[0, 2].plot(x_3, iquad_3, '-s', label='I(i)', color="forestgreen")
axes[0, 2].plot(x_3, oquad_3, '--D', label='O(i)', color="mediumslateblue")
axes[0, 2].set_title("Soc-EmailEu", fontsize=16)
axes[0, 2].legend(loc='lower right', prop={'size': 12})
axes[0, 2].set_xscale('log')
axes[0, 2].set_yscale('log')

axes[0, 3].plot(x_4[2:], iquad_4[2:], '-s', label='I(i)', color="forestgreen")
axes[0, 3].plot(x_4[2:], oquad_4[2:], '--D', label='O(i)', color="mediumslateblue")
axes[0, 3].set_title("Soc-ClgMsg", fontsize=16)
axes[0, 3].legend(loc='lower right', prop={'size': 12})
axes[0, 3].set_xscale('log')
axes[0, 3].set_yscale('log')

axes[1, 0].plot(x_5[3:], iquad_5[3:], '-s', label='I(i)', color="forestgreen")
axes[1, 0].plot(x_5[3:], oquad_5[3:], '--D', label='O(i)', color="mediumslateblue")
axes[1, 0].set_title("Soc-BTCAlpha", fontsize=16)
axes[1, 0].legend(loc='lower right', prop={'size': 12})
axes[1, 0].set_ylabel("i-quad/o-quad coefs.", fontsize=12)
axes[1, 0].set_xscale('log')
axes[1, 0].set_yscale('log')

axes[1, 1].plot(x_6, iquad_6, '-s', label='I(i)', color="forestgreen")
axes[1, 1].plot(x_6, oquad_6, '--D', label='O(i)', color="mediumslateblue")
axes[1, 1].set_title("Soc-TwitchFr", fontsize=16)
axes[1, 1].legend(loc='lower right', prop={'size': 12})
axes[1, 1].set_xscale('log')
axes[1, 1].set_yscale('log')

axes[1, 2].plot(x_7[4:], iquad_7[4:], '-s', label='I(i)', color="forestgreen")
axes[1, 2].plot(x_7[4:], oquad_7[4:], '--D', label='O(i)', color="mediumslateblue")
axes[1, 2].set_title("PPI-Stelzl", fontsize=16)
axes[1, 2].legend(loc='lower right', prop={'size': 12})
axes[1, 2].set_xscale('log')
axes[1, 2].set_yscale('log')

axes[1, 3].plot(x_8[4:], iquad_8[4:], '-s', label='I(i)', color="forestgreen")
axes[1, 3].plot(x_8[4:], oquad_8[4:], '--D', label='O(i)', color="mediumslateblue")
axes[1, 3].set_title("PPI-Figeys", fontsize=16)
axes[1, 3].legend(loc='lower right', prop={'size': 12})
axes[1, 3].set_xscale('log')
axes[1, 3].set_yscale('log')

axes[2, 0].plot(x_9[3:], iquad_9[3:], '-s', label='I(i)', color="forestgreen")
axes[2, 0].plot(x_9[3:], oquad_9[3:], '--D', label='O(i)', color="mediumslateblue")
axes[2, 0].set_title("PPI-Vidal", fontsize=16)
axes[2, 0].legend(loc='lower right', prop={'size': 12})
axes[2, 0].set_ylabel("i-quad/o-quad coefs.", fontsize=12)
axes[2, 0].set_xscale('log')
axes[2, 0].set_yscale('log')

axes[2, 1].plot(x_10[3:], iquad_10[3:], '-s', label='I(i)', color="forestgreen")
axes[2, 1].plot(x_10[3:], oquad_10[3:], '--D', label='O(i)', color="mediumslateblue")
axes[2, 1].set_title("PPI-IntAct", fontsize=16)
axes[2, 1].legend(loc='lower right', prop={'size': 12})
axes[2, 1].set_xscale('log')
axes[2, 1].set_yscale('log')

axes[2, 2].plot(x_11[3:], iquad_11[3:], '-s', label='I(i)', color="forestgreen")
axes[2, 2].plot(x_11[3:], oquad_11[3:], '--D', label='O(i)', color="mediumslateblue")
axes[2, 2].set_title("Cit-DBLP", fontsize=16)
axes[2, 2].legend(loc='lower right', prop={'size': 12})
axes[2, 2].set_xscale('log')
axes[2, 2].set_yscale('log')

axes[2, 3].plot(x_12[1:], iquad_12[1:], '-s', label='I(i)', color="forestgreen")
axes[2, 3].plot(x_12[1:], oquad_12[1:], '--D', label='O(i)', color="mediumslateblue")
axes[2, 3].set_title("Cit-Cora", fontsize=16)
axes[2, 3].legend(loc='lower right', prop={'size': 12})
axes[2, 3].set_xscale('log')
axes[2, 3].set_yscale('log')

axes[3, 0].plot(x_13[1:], iquad_13[1:], '-s', label='I(i)', color="forestgreen")
axes[3, 0].plot(x_13[1:], oquad_13[1:], '--D', label='O(i)', color="mediumslateblue")
axes[3, 0].set_title("Rd-NewYork", fontsize=16)
axes[3, 0].legend(loc='lower right', prop={'size': 12})
axes[3, 0].set_xlabel("degree", fontsize=12)
axes[3, 0].set_ylabel("i-quad/o-quad coefs.", fontsize=12)
axes[3, 0].set_xscale('log')
axes[3, 0].set_yscale('log')

axes[3, 1].plot(x_14[2:], iquad_14[2:], '-s', label='I(i)', color="forestgreen")
axes[3, 1].plot(x_14[2:], oquad_14[2:], '--D', label='O(i)', color="mediumslateblue")
axes[3, 1].set_title("Rd-BayArea", fontsize=16)
axes[3, 1].legend(loc='lower right', prop={'size': 12})
axes[3, 1].set_xlabel("degree", fontsize=12)
axes[3, 1].set_xscale('log')
axes[3, 1].set_yscale('log')

axes[3, 2].plot(x_15[4:], iquad_15[4:], '-s', label='I(i)', color="forestgreen")
axes[3, 2].plot(x_15[4:], oquad_15[4:], '--D', label='O(i)', color="mediumslateblue")
axes[3, 2].set_title("QA-MathOvfl.", fontsize=16)
axes[3, 2].legend(loc='lower right', prop={'size': 12})
axes[3, 2].set_xlabel("degree", fontsize=12)
axes[3, 2].set_xscale('log')
axes[3, 2].set_yscale('log')

axes[3, 3].plot(x_16[5:], iquad_16[5:], '-s', label='I(i)', color="forestgreen")
axes[3, 3].plot(x_16[5:], oquad_16[5:], '--D', label='O(i)', color="mediumslateblue")
axes[3, 3].set_title("QA-AskUbuntu", fontsize=16)
axes[3, 3].legend(loc='lower right', prop={'size': 12})
axes[3, 3].set_xlabel("degree", fontsize=12)
axes[3, 3].set_xscale('log')
axes[3, 3].set_yscale('log')

plt.savefig('Corr_with_degree_all.pdf')
plt.show()
