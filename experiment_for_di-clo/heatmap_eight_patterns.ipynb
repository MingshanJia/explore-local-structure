# %%
import networkx as nx
import random
import pickle
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Soc_Alpha = nx.read_edgelist("datasets/BTC-Alpha", delimiter = ',', create_using=nx.DiGraph, data=(('weight', int),('sec', int),))
Soc_OTC = nx.read_edgelist("datasets/BTC-OTC", delimiter = ',', create_using=nx.DiGraph, data=(('weight', int),('sec', float),))
Soc_Advogato = nx.read_edgelist("datasets/Soc_Advogato.csv", delimiter = ',', create_using=nx.DiGraph, data=(('weight', float),))
Soc_Epinions = nx.read_edgelist("datasets/Soc_Epinions.csv", delimiter = ',', create_using=nx.DiGraph)

FW_Mangwet = nx.read_edgelist("datasets/FW-Mangwet", create_using=nx.DiGraph, data = (('weight', float),))
FW_Baywet = nx.read_edgelist("datasets/FW-Baywet", create_using=nx.DiGraph, data = (('weight', float),))
FW_Baydry = nx.read_edgelist("datasets/FW-Baydry", create_using=nx.DiGraph, data = (('weight', float),))
FW_LittleRock = nx.read_edgelist("datasets/FW-LittleRock", create_using=nx.DiGraph)

Cit_Cora = nx.read_edgelist("datasets/Cit-Cora", create_using=nx.DiGraph)
Cit_HepTh = nx.read_edgelist("datasets/Cit-HepTh", create_using=nx.DiGraph)
Cit_HepPh = nx.read_edgelist("datasets/Cit-HepPh", create_using=nx.DiGraph)
Cit_Citeseer = nx.read_edgelist("datasets/Cit-Citeseer", delimiter = ',', create_using=nx.DiGraph)

SW_Weka = nx.read_edgelist("datasets/SW_Weka", create_using=nx.DiGraph)
SW_Lucene = nx.read_edgelist("datasets/SW_Lucene", create_using=nx.DiGraph, data=(('weight', str),))
SW_Jung = nx.read_edgelist("datasets/SW_Jung.csv", delimiter = ',', create_using=nx.DiGraph)
SW_Jdk = nx.read_edgelist("datasets/SW_Jdk.csv", delimiter = ',', create_using=nx.DiGraph)

Web_Stanford = nx.read_edgelist("datasets/web-Stanford.txt", create_using=nx.DiGraph)
Web_NotreDame = nx.read_edgelist("datasets/web-NotreDame.txt", create_using=nx.DiGraph)
Web_BerkStan = nx.read_edgelist("datasets/web-BerkStan.txt", create_using=nx.DiGraph)
Web_Google = nx.read_edgelist("datasets/web-Google.txt", create_using=nx.DiGraph)

WordAdj_Jp = nx.read_edgelist("datasets/WordAdj_Jp.csv", delimiter = ',', create_using=nx.DiGraph)
WordAdj_Drw = nx.read_edgelist("datasets/WordAdj_Drw.csv", delimiter = ',', create_using=nx.DiGraph)
WordAdj_Fr = nx.read_edgelist("datasets/WordAdj_Fr.csv", delimiter = ',', create_using=nx.DiGraph)
WordAdj_Spa = nx.read_edgelist("datasets/WordAdj_Spa.csv", delimiter = ',', create_using=nx.DiGraph)

# %%
# word adjacency
japan = nx.get_eight_patterns_df(WordAdj_Jp)
darwin = nx.get_eight_patterns_df(WordAdj_Drw)
french = nx.get_eight_patterns_df(WordAdj_Fr)
spanish = nx.get_eight_patterns_df(WordAdj_Spa)
with open('eight_patterns_df/wa-japanese', 'wb') as fp:
    pickle.dump(japan, fp)
with open('eight_patterns_df/wa-darwin', 'wb') as fp:
    pickle.dump(darwin, fp)
with open('eight_patterns_df/wa-french', 'wb') as fp:
    pickle.dump(french, fp)
with open('eight_patterns_df/wa-spanish', 'wb') as fp:
    pickle.dump(spanish, fp)

# %%
with open ('eight_patterns_df/wa-japanese', 'rb') as fp:
    japan = pickle.load(fp)
with open ('eight_patterns_df/wa-darwin', 'rb') as fp:
    darwin = pickle.load(fp)
with open ('eight_patterns_df/wa-french', 'rb') as fp:
    french = pickle.load(fp)
with open ('eight_patterns_df/wa-spanish', 'rb') as fp:
    spanish = pickle.load(fp)

# %%
# web graph
stanford = nx.get_eight_patterns_df(Web_Stanford)
notredame = nx.get_eight_patterns_df(Web_NotreDame)
berkstan = nx.get_eight_patterns_df(Web_BerkStan)
google = nx.get_eight_patterns_df(Web_Google)
with open('eight_patterns_df/web-stanford', 'wb') as fp:
    pickle.dump(stanford, fp)
with open('eight_patterns_df/web-notredame', 'wb') as fp:
    pickle.dump(notredame, fp)
with open('eight_patterns_df/web-berkstan', 'wb') as fp:
    pickle.dump(berkstan, fp)
with open('eight_patterns_df/web-google', 'wb') as fp:
    pickle.dump(google, fp)

# %%
with open ('eight_patterns_df/web-stanford', 'rb') as fp:
    stanford = pickle.load(fp)
with open ('eight_patterns_df/web-notredame', 'rb') as fp:
    notredame = pickle.load(fp)
with open ('eight_patterns_df/web-berkstan', 'rb') as fp:
    berkstan = pickle.load(fp)
with open ('eight_patterns_df/web-google', 'rb') as fp:
    google = pickle.load(fp)

# %%
# software
weka = nx.get_eight_patterns_df(SW_Weka)
lucene = nx.get_eight_patterns_df(SW_Lucene)
jung = nx.get_eight_patterns_df(SW_Jung)
jdk = nx.get_eight_patterns_df(SW_Jdk)
with open('eight_patterns_df/sw-weka', 'wb') as fp:
    pickle.dump(weka, fp)
with open('eight_patterns_df/sw-lucene', 'wb') as fp:
    pickle.dump(lucene, fp)
with open('eight_patterns_df/sw-jung', 'wb') as fp:
    pickle.dump(jung, fp)
with open('eight_patterns_df/sw-jdk', 'wb') as fp:
    pickle.dump(jdk, fp)

# %%
with open ('eight_patterns_df/sw-weka', 'rb') as fp:
    weka = pickle.load(fp)
with open ('eight_patterns_df/sw-lucene', 'rb') as fp:
    lucene = pickle.load(fp)
with open ('eight_patterns_df/sw-jung', 'rb') as fp:
    jung = pickle.load(fp)
with open ('eight_patterns_df/sw-jdk', 'rb') as fp:
    jdk = pickle.load(fp)

# %%
# citation
cora = nx.get_eight_patterns_df(Cit_Cora)
hepth = nx.get_eight_patterns_df(Cit_HepTh)
hepph = nx.get_eight_patterns_df(Cit_HepPh)
citeseer = nx.get_eight_patterns_df(Cit_Citeseer)
with open('eight_patterns_df/cit-cora', 'wb') as fp:
    pickle.dump(cora, fp)
with open('eight_patterns_df/cit-hepTh', 'wb') as fp:
    pickle.dump(hepth, fp)
with open('eight_patterns_df/cit-hepPh', 'wb') as fp:
    pickle.dump(hepph, fp)
with open('eight_patterns_df/cit-citeseer', 'wb') as fp:
    pickle.dump(citeseer, fp)

# %%
with open ('eight_patterns_df/cit-cora', 'rb') as fp:
    cora = pickle.load(fp)
with open ('eight_patterns_df/cit-hepTh', 'rb') as fp:
    hepth = pickle.load(fp)
with open ('eight_patterns_df/cit-hepPh', 'rb') as fp:
    hepph = pickle.load(fp)
with open ('eight_patterns_df/cit-citeseer', 'rb') as fp:
    citeseer = pickle.load(fp)

# %%
# trust
alpha = nx.get_eight_patterns_df(Soc_Alpha)
otc = nx.get_eight_patterns_df(Soc_OTC)
advogato = nx.get_eight_patterns_df(Soc_Advogato)
epinions = nx.get_eight_patterns_df(Soc_Epinions)
with open('eight_patterns_df/soc-alpha', 'wb') as fp:
    pickle.dump(alpha, fp)
with open('eight_patterns_df/soc-otc', 'wb') as fp:
    pickle.dump(otc, fp)
with open('eight_patterns_df/soc-advogato', 'wb') as fp:
    pickle.dump(advogato, fp)
with open('eight_patterns_df/soc-epinions', 'wb') as fp:
    pickle.dump(epinions, fp)

# %%
with open ('eight_patterns_df/soc-alpha', 'rb') as fp:
    alpha = pickle.load(fp)
with open ('eight_patterns_df/soc-otc', 'rb') as fp:
    otc = pickle.load(fp)
with open ('eight_patterns_df/soc-advogato', 'rb') as fp:
    advogato = pickle.load(fp)
with open ('eight_patterns_df/soc-epinions', 'rb') as fp:
    epinions = pickle.load(fp)

# %%
# foodweb
mang = nx.get_eight_patterns_df(FW_Mangwet)
baywet = nx.get_eight_patterns_df(FW_Baywet)
baydry = nx.get_eight_patterns_df(FW_Baydry)
littlerock = nx.get_eight_patterns_df(FW_LittleRock)
with open('eight_patterns_df/fw-mang', 'wb') as fp:
    pickle.dump(mang, fp)
with open('eight_patterns_df/fw-baywet', 'wb') as fp:
    pickle.dump(baywet, fp)
with open('eight_patterns_df/fw-baydry', 'wb') as fp:
    pickle.dump(baydry, fp)
with open('eight_patterns_df/fw-littlerock', 'wb') as fp:
    pickle.dump(littlerock, fp)

# %%
with open ('eight_patterns_df/fw-mang', 'rb') as fp:
    mang = pickle.load(fp)
with open ('eight_patterns_df/fw-baywet', 'rb') as fp:
    baywet = pickle.load(fp)
with open ('eight_patterns_df/fw-baydry', 'rb') as fp:
    baydry = pickle.load(fp)
with open ('eight_patterns_df/fw-littlerock', 'rb') as fp:
    littlerock = pickle.load(fp)

# %%
## 6 networks
# onepic, axes = plt.subplots(2,3,figsize=(15,7), sharex=True, sharey=True)
# plt.subplots_adjust(hspace=0.15, wspace=.15)
# # add only one color bar for all subplots
# cbar_ax = onepic.add_axes([.9, .08, .022, .86])

# sns.heatmap(alpha.corr(), ax=axes[0][0], cbar=True, cbar_ax=cbar_ax, cmap="Blues")
# axes[0, 0].set_title("Tr-BTCAlpha", fontsize=16)
# axes[0, 0].tick_params('y', labelsize=14)

# sns.heatmap(baydry.corr(), ax=axes[0][1], cbar=False, cmap="Blues")
# axes[0, 1].set_title("FW-BayDry", fontsize=16)

# sns.heatmap(hepth.corr(), ax=axes[0][2], cbar=False, cmap="Blues")
# axes[0, 2].set_title("Cit-HepTh", fontsize=16)

# sns.heatmap(jdk.corr(), ax=axes[1][0], cbar=False, cmap="Blues")
# axes[1, 0].set_title("SW-JDK", fontsize=16)
# axes[1, 0].tick_params('x', labelsize=14)
# axes[1, 0].tick_params('y', labelsize=14)

# sns.heatmap(google.corr(), ax=axes[1][1], cbar=False, cmap="Blues")
# axes[1, 1].set_title("Web-Google", fontsize=16)
# axes[1, 1].tick_params('x', labelsize=14)

# sns.heatmap(french.corr(), ax=axes[1][2], cbar=False, cmap="Blues")
# axes[1, 2].set_title("WA-French", fontsize=16)
# axes[1, 2].tick_params('x', labelsize=14)

# onepic.tight_layout(rect=[0, 0, 0.9, 1])
# plt.savefig('heatmap.pdf')

# %% [markdown]
# #### Different types of network exhibit different correlations among the eight patterns
# - In trust network (BTCAlpha), we observe high correlations among the four closure patterns, or among the four clustering patterns; In contrast, the correlations between the closure patterns and the clustering patterns are very low.
# - In word ajacency network (French), we only find high correlations among the four closure patterns.
# - In web graph (Google), there are also relatively high correlations among the four closure patterns (except between closure-head and closure-end)
# - In food web (BayDry), citation network (HepTh) and software network (JDK), high correlations among the eight patterns are rare, such as the correlation between closure-cyc and clustering-cyc.

# %%
# onepic, axes = plt.subplots(4,6,figsize=(19,10), sharex=True, sharey=True)
# plt.subplots_adjust(hspace=0.15, wspace=.15)
# # add only one color bar for all subplots
# cbar_ax = onepic.add_axes([.9, .07, .022, .89])

# sns.heatmap(alpha.corr(), ax=axes[0][0], cbar=True, cbar_ax=cbar_ax, cmap="Blues")
# axes[0, 0].set_title("Tr-BTCAlpha", fontsize=16)
# sns.heatmap(otc.corr(), ax=axes[0][1], cbar=False, cmap="Blues")
# axes[0, 1].set_title("Tr-BTC-OTC", fontsize=16)
# sns.heatmap(advogato.corr(), ax=axes[0][2], cbar=False, cmap="Blues")
# axes[0, 2].set_title("Tr-Advogato", fontsize=16)
# sns.heatmap(epinions.corr(), ax=axes[0][3], cbar=False, cmap="Blues")
# axes[0, 3].set_title("Tr-Epinions", fontsize=16)

# sns.heatmap(mang.corr(), ax=axes[0][4], cbar=False, cmap="Blues")
# axes[0, 4].set_title("FW-Mangrove", fontsize=16)
# sns.heatmap(baywet.corr(), ax=axes[0][5], cbar=False, cmap="Blues")
# axes[0, 5].set_title("FW-BayWet", fontsize=16)
# sns.heatmap(baydry.corr(), ax=axes[1][0], cbar=False, cmap="Blues")
# axes[1, 0].set_title("FW-BayDry", fontsize=16)
# sns.heatmap(littlerock.corr(), ax=axes[1][1], cbar=False, cmap="Blues")
# axes[1, 1].set_title("FW-LittleRock", fontsize=16)

# sns.heatmap(cora.corr(), ax=axes[1][2], cbar=False, cmap="Blues")
# axes[1, 2].set_title("Cit-Cora", fontsize=16)
# sns.heatmap(hepth.corr(), ax=axes[1][3], cbar=False, cmap="Blues")
# axes[1, 3].set_title("Cit-HepTh", fontsize=16)
# sns.heatmap(hepph.corr(), ax=axes[1][4], cbar=False, cmap="Blues")
# axes[1, 4].set_title("Cit-HepPh", fontsize=16)
# sns.heatmap(citeseer.corr(), ax=axes[1][5], cbar=False, cmap="Blues")
# axes[1, 5].set_title("Cit-Citeseer", fontsize=16)

# sns.heatmap(weka.corr(), ax=axes[2][0], cbar=False, cmap="Blues")
# axes[2, 0].set_title("SW-Weka", fontsize=16)
# sns.heatmap(lucene.corr(), ax=axes[2][1], cbar=False, cmap="Blues")
# axes[2, 1].set_title("SW-Lucene", fontsize=16)
# sns.heatmap(jung.corr(), ax=axes[2][2], cbar=False, cmap="Blues")
# axes[2, 2].set_title("SW-JUNG", fontsize=16)
# sns.heatmap(jdk.corr(), ax=axes[2][3], cbar=False, cmap="Blues")
# axes[2, 3].set_title("SW-JDK", fontsize=16)

# sns.heatmap(stanford.corr(), ax=axes[2][4], cbar=False, cmap="Blues")
# axes[2, 4].set_title("Web-Stanford", fontsize=16)
# sns.heatmap(notredame.corr(), ax=axes[2][5], cbar=False, cmap="Blues")
# axes[2, 5].set_title("Web-NotreDame", fontsize=16)
# sns.heatmap(berkstan.corr(), ax=axes[3][0], cbar=False, cmap="Blues")
# axes[3, 0].set_title("Web-BerkStan", fontsize=16)
# sns.heatmap(google.corr(), ax=axes[3][1], cbar=False, cmap="Blues")
# axes[3, 1].set_title("Web-Google", fontsize=16)

# sns.heatmap(japan.corr(), ax=axes[3][2], cbar=False, cmap="Blues")
# axes[3, 2].set_title("WA-Japanese", fontsize=16)
# sns.heatmap(darwin.corr(), ax=axes[3][3], cbar=False, cmap="Blues")
# axes[3, 3].set_title("WA-NotreDame", fontsize=16)
# sns.heatmap(french.corr(), ax=axes[3][4], cbar=False, cmap="Blues")
# axes[3, 4].set_title("WA-French", fontsize=16)
# sns.heatmap(spanish.corr(), ax=axes[3][5], cbar=False, cmap="Blues")
# axes[3, 5].set_title("WA-Spanish", fontsize=16)

# onepic.tight_layout(rect=[0, 0, 0.9, 1])
# plt.savefig('heatmap_all.pdf')

# %%
onepic, axes = plt.subplots(6,4,figsize=(11.3,12.3), sharex=True, sharey=True)
plt.subplots_adjust(hspace=0.15, wspace=.15)
# add only one color bar for all subplots
# left, bottom, width, height
cbar_ax = onepic.add_axes([.9, .086, .02, .881])

sns.heatmap(alpha.corr(), ax=axes[0][0], cbar=True, cbar_ax=cbar_ax, cmap="coolwarm")
axes[0, 0].set_title("Tr-BTCAlpha", fontsize=16)
axes[0, 0].tick_params('y', labelsize=16)
sns.heatmap(otc.corr(), ax=axes[0][1], cbar=False, cmap="coolwarm")
axes[0, 1].set_title("Tr-BTC-OTC", fontsize=16)
sns.heatmap(advogato.corr(), ax=axes[0][2], cbar=False, cmap="coolwarm")
axes[0, 2].set_title("Tr-Advogato", fontsize=16)
sns.heatmap(epinions.corr(), ax=axes[0][3], cbar=False, cmap="coolwarm")
axes[0, 3].set_title("Tr-Epinions", fontsize=16)

sns.heatmap(mang.corr(), ax=axes[1][0], cbar=False, cmap="coolwarm")
axes[1, 0].set_title("FW-Mangrove", fontsize=16)
axes[1, 0].tick_params('y', labelsize=16)
sns.heatmap(baywet.corr(), ax=axes[1][1], cbar=False, cmap="coolwarm")
axes[1, 1].set_title("FW-BayWet", fontsize=16)
sns.heatmap(baydry.corr(), ax=axes[1][2], cbar=False, cmap="coolwarm")
axes[1, 2].set_title("FW-BayDry", fontsize=16)
sns.heatmap(littlerock.corr(), ax=axes[1][3], cbar=False, cmap="coolwarm")
axes[1, 3].set_title("FW-LittleRock", fontsize=16)

sns.heatmap(cora.corr(), ax=axes[2][0], cbar=False, cmap="coolwarm")
axes[2, 0].set_title("Cit-Cora", fontsize=16)
axes[2, 0].tick_params('y', labelsize=16)
sns.heatmap(hepth.corr(), ax=axes[2][1], cbar=False, cmap="coolwarm")
axes[2, 1].set_title("Cit-HepTh", fontsize=16)
sns.heatmap(hepph.corr(), ax=axes[2][2], cbar=False, cmap="coolwarm")
axes[2, 2].set_title("Cit-HepPh", fontsize=16)
sns.heatmap(citeseer.corr(), ax=axes[2][3], cbar=False, cmap="coolwarm")
axes[2, 3].set_title("Cit-Citeseer", fontsize=16)

sns.heatmap(weka.corr(), ax=axes[3][0], cbar=False, cmap="coolwarm")
axes[3, 0].set_title("SW-Weka", fontsize=16)
axes[3, 0].tick_params('y', labelsize=16)
sns.heatmap(lucene.corr(), ax=axes[3][1], cbar=False, cmap="coolwarm")
axes[3, 1].set_title("SW-Lucene", fontsize=16)
sns.heatmap(jung.corr(), ax=axes[3][2], cbar=False, cmap="coolwarm")
axes[3, 2].set_title("SW-JUNG", fontsize=16)
sns.heatmap(jdk.corr(), ax=axes[3][3], cbar=False, cmap="coolwarm")
axes[3, 3].set_title("SW-JDK", fontsize=16)

sns.heatmap(stanford.corr(), ax=axes[4][0], cbar=False, cmap="coolwarm")
axes[4, 0].set_title("Web-Stanford", fontsize=16)
axes[4, 0].tick_params('y', labelsize=16)
sns.heatmap(notredame.corr(), ax=axes[4][1], cbar=False, cmap="coolwarm")
axes[4, 1].set_title("Web-NotreDame", fontsize=16)
sns.heatmap(berkstan.corr(), ax=axes[4][2], cbar=False, cmap="coolwarm")
axes[4, 2].set_title("Web-BerkStan", fontsize=16)
sns.heatmap(google.corr(), ax=axes[4][3], cbar=False, cmap="coolwarm")
axes[4, 3].set_title("Web-Google", fontsize=16)

sns.heatmap(japan.corr(), ax=axes[5][0], cbar=False, cmap="coolwarm")
axes[5, 0].set_title("WA-Japanese", fontsize=16)
axes[5, 0].tick_params('x', labelsize=16)
axes[5, 0].tick_params('y', labelsize=16)
sns.heatmap(darwin.corr(), ax=axes[5][1], cbar=False, cmap="coolwarm")
axes[5, 1].set_title("WA-NotreDame", fontsize=16)
axes[5, 1].tick_params('x', labelsize=16)
sns.heatmap(french.corr(), ax=axes[5][2], cbar=False, cmap="coolwarm")
axes[5, 2].set_title("WA-French", fontsize=16)
axes[5, 2].tick_params('x', labelsize=16)
sns.heatmap(spanish.corr(), ax=axes[5][3], cbar=False, cmap="coolwarm")
axes[5, 3].set_title("WA-Spanish", fontsize=16)
axes[5, 3].tick_params('x', labelsize=16)

onepic.tight_layout(rect=[0, 0, 0.9, 1])
plt.savefig('heatmap_all.pdf')
